# %% [markdown]
# # Dataanalys #
#
# Här går vi igenom datan som vi hämtar från rikstans databas som kommer att användas för att träna modellerna.

# %%
import numpy as np
import pandas as pd

# %%
members.info()
print(members.head())
print(members['parti'].unique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 members.info()
#       2 print(members.head())
#       3 print(members['parti'].unique())
#
# NameError: name 'members' is not defined

# %%
anforande_202324 = pd.read_csv(
    'documents/anforande-202324.csv',
    header=0,
    names = [
    'dok_id', 
    'dok_rm', 
    'dok_nummer', 
    'dok_datum', 
    'avsnittsrubrik', 
    'kammaraktivitet', 
    'anforande_nummer', 
    'talare', 
    'parti', 
    'intressent_id', 
    'rel_dok_id', 
    'replik'],
    dtype={
        'intressent_id': 'string'
    }
) 
anforande_202324["dok_id"].unique()
# Out:
# array(['HB09100', 'HB09101', 'HB09102', 'HB09103', 'HB09104', 'HB09105',
#        'HB09106', 'HB09107', 'HB09108', 'HB09109', 'HB0911', 'HB09110',
#        'HB09111', 'HB09112', 'HB09113', 'HB09114', 'HB09115', 'HB09116',
#        'HB09117', 'HB09118', 'HB09119', 'HB0912', 'HB09120', 'HB09121',
#        'HB09122', 'HB09123', 'HB09124', 'HB09125', 'HB09126', 'HB09128',
#        'HB09129', 'HB0913', 'HB09130', 'HB09131', 'HB09132', 'HB09133',
#        'HB09134', 'HB09135', 'HB09136', 'HB09137', 'HB09138', 'HB09139',
#        'HB09140', 'HB09141', 'HB0915', 'HB0916', 'HB0917', 'HB0918',
#        'HB0919', 'HB092', 'HB0920', 'HB0921', 'HB0922', 'HB0923',
#        'HB0924', 'HB0925', 'HB0926', 'HB0927', 'HB0928', 'HB0929',
#        'HB093', 'HB0930', 'HB0931', 'HB0932', 'HB0933', 'HB0934',
#        'HB0935', 'HB0936', 'HB0937', 'HB0938', 'HB0939', 'HB094',
#        'HB0940', 'HB0941', 'HB0942', 'HB0943', 'HB0944', 'HB0945',
# ...

# %%
print(anforande_202324[anforande_202324["dok_id"] == "HB09124"])
# Out:
#        dok_id   dok_rm  dok_nummer            dok_datum  \
# 2954  HB09124  2023/24         124  2024-05-29 00:00:00
# 2955  HB09124  2023/24         124  2024-05-29 00:00:00
# 2956  HB09124  2023/24         124  2024-05-29 00:00:00
# 2957  HB09124  2023/24         124  2024-05-29 00:00:00
# 2958  HB09124  2023/24         124  2024-05-29 00:00:00
# ...       ...      ...         ...                  ...
# 3028  HB09124  2023/24         124  2024-05-29 00:00:00
# 3029  HB09124  2023/24         124  2024-05-29 00:00:00
# 3030  HB09124  2023/24         124  2024-05-29 00:00:00
# 3031  HB09124  2023/24         124  2024-05-29 00:00:00
# 3032  HB09124  2023/24         124  2024-05-29 00:00:00
#
#                                          avsnittsrubrik kammaraktivitet  \
# 2954  Vissa förslag om kompensation m.m. till person...    ärendedebatt
# 2955  Vissa förslag om kompensation m.m. till person...    ärendedebatt
# 2956  Vissa förslag om kompensation m.m. till person...    ärendedebatt
# ...

# %%
anforande_202223
# Out:
#        dok_id   dok_rm  dok_nummer            dok_datum  \
# 0       HA091  2022/23           1  2022-09-26 00:00:00
# 1       HA091  2022/23           1  2022-09-26 00:00:00
# 2       HA091  2022/23           1  2022-09-26 00:00:00
# 3       HA091  2022/23           1  2022-09-26 00:00:00
# 4       HA091  2022/23           1  2022-09-26 00:00:00
# ...       ...      ...         ...                  ...
# 12474  HA0999  2022/23          99  2023-04-27 00:00:00
# 12475  HA0999  2022/23          99  2023-04-27 00:00:00
# 12476  HA0999  2022/23          99  2023-04-27 00:00:00
# 12477  HA0999  2022/23          99  2023-04-27 00:00:00
# 12478  HA0999  2022/23          99  2023-04-27 00:00:00
#
#                   avsnittsrubrik kammaraktivitet  anforande_nummer  \
# 0      Val av förste vice talman             NaN                10
# 1      Val av förste vice talman             NaN                11
# 2       Val av andre vice talman             NaN                12
# ...

# %%
votering_202223 = pd.read_csv('documents/votering-202223.csv')
votering_202223.info()
print(votering_202223.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196835 entries, 0 to 196834
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   2022/23                               196835 non-null  object
#  1   UU15                                  196835 non-null  object
#  2   008484EA-7970-4559-BEA7-E2F6454E7571  196835 non-null  object
#  3   5                                     196835 non-null  int64
#  4   Julia Kronlid                         196835 non-null  object
#  5   0638497389621                         196835 non-null  int64
#  6   SD                                    196835 non-null  object
#  7   Stockholms län                        196835 non-null  object
#  8   Frånvarande                           196835 non-null  object
#  9   sakfrågan                             196835 non-null  object
# ...

# %%
votering_columns = [
    'rm',
    'beteckning',
    'votering_id',
    'punkt',
    'namn',
    'intressent_id',
    'parti',
    'valkrets',
    'rost',
    'avser',
    'banknummer',
    'kön',
    'fodd',
    'system_datum'
]
votering_202223 = pd.read_csv(
    'documents/votering-202223.csv',
    header=0,
    names=votering_columns,
    dtype={ 'intressent_id': 'string' }
)

votering_202223
# Out:
#              rm beteckning                           votering_id  punkt  \
# 0       2022/23       UU15  008484EA-7970-4559-BEA7-E2F6454E7571      5
# 1       2022/23       UU15  008484EA-7970-4559-BEA7-E2F6454E7571      5
# 2       2022/23       UU15  008484EA-7970-4559-BEA7-E2F6454E7571      5
# 3       2022/23       UU15  008484EA-7970-4559-BEA7-E2F6454E7571      5
# 4       2022/23       UU15  008484EA-7970-4559-BEA7-E2F6454E7571      5
# ...         ...        ...                                   ...    ...
# 196830  2022/23        CU6  FFC81C4F-0CB8-4972-A18D-4E4C62BFC19B     23
# 196831  2022/23        CU6  FFC81C4F-0CB8-4972-A18D-4E4C62BFC19B     23
# 196832  2022/23        CU6  FFC81C4F-0CB8-4972-A18D-4E4C62BFC19B     23
# 196833  2022/23        CU6  FFC81C4F-0CB8-4972-A18D-4E4C62BFC19B     23
# 196834  2022/23        CU6  FFC81C4F-0CB8-4972-A18D-4E4C62BFC19B     23
#
#                         namn  intressent_id parti             valkrets  \
# ...

# %%
votering_202223.columns = [
    'rm',
    'beteckning',
    'votering_id',
    'punkt',
    'namn',
    'intressent_id',
    'parti',
    'valkrets',
    'rost',
    'avser',
    'banknummer',
    'kön',
    'fodd',
    'system_datum'
]

votering_202223
# Out:
#              rm beteckning                           votering_id  punkt  \
# 0       2022/23       UU15  008484EA-7970-4559-BEA7-E2F6454E7571      5
# 1       2022/23       UU15  008484EA-7970-4559-BEA7-E2F6454E7571      5
# 2       2022/23       UU15  008484EA-7970-4559-BEA7-E2F6454E7571      5
# 3       2022/23       UU15  008484EA-7970-4559-BEA7-E2F6454E7571      5
# 4       2022/23       UU15  008484EA-7970-4559-BEA7-E2F6454E7571      5
# ...         ...        ...                                   ...    ...
# 196830  2022/23        CU6  FFC81C4F-0CB8-4972-A18D-4E4C62BFC19B     23
# 196831  2022/23        CU6  FFC81C4F-0CB8-4972-A18D-4E4C62BFC19B     23
# 196832  2022/23        CU6  FFC81C4F-0CB8-4972-A18D-4E4C62BFC19B     23
# 196833  2022/23        CU6  FFC81C4F-0CB8-4972-A18D-4E4C62BFC19B     23
# 196834  2022/23        CU6  FFC81C4F-0CB8-4972-A18D-4E4C62BFC19B     23
#
#                         namn  intressent_id parti             valkrets  \
# ...

# %%
anforande_202223.loc[1]
# Out:
# dok_id                                  HA091
# dok_rm                                2022/23
# dok_nummer                                  1
# dok_datum                 2022-09-26 00:00:00
# avsnittsrubrik      Val av förste vice talman
# kammaraktivitet                           NaN
# anforande_nummer                           11
# talare                         Annie Lööf (C)
# parti                                       C
# intressent_id                   0862868280923
# rel_dok_id                                NaN
# replik                                      N
# Name: 1, dtype: object

# %%
print(len(anforande_202324[0]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Repos/AI-projects/gov_check/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ...

# %%
text = "HB09100	2023/24	100	2024-04-17 00:00:00	Förbättrade möjligheter att ändra kön	ärendedebatt	1	Yasmine Bladelius (S)	S	0996640018922	HB01SoU22	N"
print(len(text))
# Out:
# 142

# %%
from api_caller import fetch_document_html
from langchain_community.document_transformers import BeautifulSoupTransformer
from langchain_core.documents import Document

def get_documents(dok_ids: list[str]) -> list[dict[str, str]]:
    """
    Fetches documents by their IDs and returns a list of dictionaries containing the document content.
    """
    documents = []
    bs_transformer = BeautifulSoupTransformer()
    
    try:
        if not isinstance(dok_ids, list):
            print("Invalid input: dok_ids must be a list.")
            raise TypeError("dok_ids must be a list.")
        if len(dok_ids) == 0:
            print("No document IDs provided.")
            raise ValueError("No document IDs provided.")
        else:        
            for dok_id in dok_ids:
                document = {}
                fetched_doc = fetch_document_html(dok_id)
                cleaned = bs_transformer.transform_documents([fetched_doc], tags_to_extract=["p", "h1", "h2", "h3", "li"])

                document["dok_id"] = dok_id
                document["innehåll"] = cleaned[0].page_content

                documents.append(document)

            return documents
    
    except Exception as e:
        print(f"Error fetching documents: {e}")

documents = get_documents("sgf")
print(documents)
# Out:
# Invalid input: dok_ids must be a list.
# Error fetching documents: dok_ids must be a list.
# None

# %%
personer = pd.read_csv("documents/personer/personer")

personer.columns
# Out:
# Index(['Förnamn', 'Efternamn', 'Iort', 'Parti', 'Id', 'Kön', 'Född',
#        'Valkrets', 'Status', 'Webbadress', 'Epostadress', 'Telefonnummer',
#        'Titel', 'Uppdragstyp', 'Uppdragsorgan', 'Uppdragsroll',
#        'Uppdragsrollstatus', 'From', 'Tom'],
#       dtype='object')

# %%
columns = {
    'Förnamn': 'förnamn',
    'Efternamn': 'efternamn',
    'Parti': 'parti',
    'Id': 'intressent_id',
    'Kön': 'kön',
    'Född': 'född',
    'Valkrets': 'valktrets',

}

cleaned = pd.read_csv("documents/personer/personer", header=0, usecols=columns)

cleaned_copy = cleaned.rename(columns=columns).drop_duplicates(subset=['intressent_id']).copy()

cleaned_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 349 entries, 0 to 8723
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   förnamn        349 non-null    object
#  1   efternamn      349 non-null    object
#  2   parti          349 non-null    object
#  3   intressent_id  349 non-null    int64
#  4   kön            349 non-null    object
#  5   född           349 non-null    int64
#  6   valktrets      349 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 21.8+ KB

# %%
DATABASE_URL = "postgresql+psycopg2://gov_check_user:gov_check_pw@localhost:5432/gov_check_db"

from sqlalchemy import create_engine, text
from sqlalchemy.orm import sessionmaker

engine = create_engine(
    DATABASE_URL,
    pool_size=5,
    max_overflow=10,
    pool_pre_ping=True
)

SessionLocal = sessionmaker(
    autocommit=False,
    autoflush=False,
    bind=engine
)

# with SessionLocal() as session:
#     with session.begin():
#         session.execute(text("INSERT INTO votering (rm,beteckning,hangar_id,votering_id,punkt,namn,intressent_id,parti,valkrets,valkretsnummer,iort,rost,avser,votering,banknummer,fornamn,efternamn,kon,fodd,datum) VALUES ('2022/23','UU15',5167346,'008484EA-7970-4559-BEA7-E2F6454E7571',5,'Merit Frost Lindberg','0533104339313','M','Stockholms kommun',1,'','Ja','sakfrågan','huvud',26,'Merit','Frost Lindberg','kvinna',1973,'2023-05-10');"))


# Instantiate a session, then call .begin() on it
with SessionLocal() as sess:
    with sess.begin():
        result = sess.scalars(text("SELECT embedding FROM person LIMIT 2"))
        print(result.all())
# Out:
# ['[0.025676053,-0.0026329507,0.010524441,0.06965817,-0.0050727036,-0.037621234,0.024919631,-0.008695321,-0.026588326,-0.0007942913,0.049374256,-0.0067007616,0.028564176,0.0043143434,-0.03060792,-0.065526314,0.019550378,0.017487584,-0.039273325,-0.023817152,0.006434499,0.036852334,-0.012560278,0.049656097,0.059719186,0.008552588,-0.01636966,-0.0027456766,0.06318743,0.049733367,0.023697622,-0.06484016,-0.006996954,-0.004304735,1.6542198e-06,0.044771045,0.02459897,0.005493201,-0.04126864,0.008162664,-0.037635505,0.026822386,-0.05992357,-0.009109119,0.02402218,0.00887239,-0.01629485,-0.002573683,-0.030336395,-0.0126960995,0.009088868,0.023806853,-0.014360338,-0.016223475,0.039107658,-0.04444122,0.023239633,0.009494739,-0.0047867834,0.025640098,0.016563945,0.0305717,-0.019848108,0.017868806,-0.01174228,0.026891522,0.03920005,-0.04309983,-0.0011769118,0.0476268,0.11177799,0.0009535743,0.035141908,0.057194393,-0.022767415,0.042575657,-0.009118025,-0.029875416,-0.048883844,-0.014956226,0.012
# ...

# %%
from pathlib import Path

DOCUMENTS_PATH = Path('documents')

def utc_now():
    return datetime.now(timezone.utc)

def load_sql_paths(directory: str) -> list[Path]:
    documents_path = Path(DOCUMENTS_PATH) / directory
    return list(documents_path.glob("*.sql"))

print(load_sql_paths("anforanden"))
# Out:
# [PosixPath('documents/anforanden/anforande-202223.sql'), PosixPath('documents/anforanden/anforande-202324.sql'), PosixPath('documents/anforanden/anforande-202425.sql'), PosixPath('documents/anforanden/anforande-202526.sql')]

# %%
import re

sql_path = Path("documents/anforanden/anforande-202223.sql")
with sess.begin():
            for path in load_sql_paths(sql_path):
                print(f"Processing: {path.name}")
                raw_sql = path.read_text(encoding="utf-8")
                inserts = re.findall(r'INSERT INTO .+?;', raw_sql, re.DOTALL)

                for insert in inserts:
                    sess.execute(text(insert))

# %%
sql_path = Path("documents/anforanden/anforande-202223.sql")

raw_sql = sql_path.read_text(encoding="utf-8")
inserts = re.findall(r'INSERT INTO .+?;', raw_sql, re.DOTALL)

print(inserts[2])
# Out:
# INSERT INTO anforande (dok_hangar_id,dok_id,dok_titel,dok_rm,dok_nummer,dok_datum,avsnittsrubrik,underrubrik,kammaraktivitet,anforande_id,anforande_nummer,talare,parti,anforandetext,intressent_id,rel_dok_id,replik,systemdatum)
# ...

# %%
from sqlalchemy import text

pingas = ["pingas", "mingas", "chingas"]

table = "anforande"

col = ", ".join(f'"{ping}"' for ping in pingas)

t = text(f"SELECT {col} from {table}")

print(t)
# Out:
# SELECT "pingas", "mingas", "chingas" from anforande

# %%
from sqlalchemy import create_engine, text
from sqlalchemy.orm import sessionmaker
from langchain_huggingface import HuggingFaceEmbeddings
import torch

DATABASE_URL = "postgresql+psycopg2://gov_check_user:gov_check_pw@localhost:5432/gov_check_db"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-mpnet-base-v2",
    model_kwargs={"device": device},
    encode_kwargs={"batch_size": 128, "normalize_embeddings": True},
)

engine = create_engine(DATABASE_URL)
SessionLocal = sessionmaker(bind=engine)

query = "Vad har Magdalena Andersson sagt gällande sammarbete med Sverigedemokraterna (sd)?"
query_embedding = embeddings.embed_query(query)

with SessionLocal() as sess:
    result = sess.execute(text("""
        SELECT talare, parti, anforandetext FROM anforande ORDER BY embedding <-> CAST(:embedding AS vector) LIMIT 20
    """), {"embedding": str(query_embedding)}).fetchall()

    for row in result:
        print(f"{row.talare}")
        print(f"{row.anforandetext[:1000]}")
        print()
# Out:
# Jan Riise (MP)
# <p>Fru talman! Jag kan inte svara för Magdalena Andersson. Det är väl det kortfattade svaret på den frågan. Vi har pratat om detta vid flera tillfällen under denna debatt. Det är inte vi som är Socialdemokratiska arbetarepartiet. Varken Vänsterpartiet eller Miljöpartiet har några som helst möjligheter att ta ställning i den frågan. Lena Hallengren har på ett utmärkt sätt redovisat vad man tänker sig att göra och inte göra. Jag har inga ytterligare kommentarer till det.</p>
#
# Lena Hallengren (S)
# ...
