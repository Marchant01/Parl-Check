# %% [markdown]
# # Dataanalys #
#
# Här går vi igenom datan som vi hämtar från rikstans databas som kommer att användas för att träna modellerna.

# %%
import numpy as np
import pandas as pd
from main import get_all_members

members = pd.json_normalize(get_all_members()['personlista']['person'])

# %%
members.info()
print(members.head())
print(members['parti'].unique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 349 entries, 0 to 348
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   hangar_guid            349 non-null    object
#  1   sourceid               349 non-null    object
#  2   intressent_id          349 non-null    object
#  3   hangar_id              349 non-null    object
#  4   fodd_ar                349 non-null    object
#  5   kon                    349 non-null    object
#  6   efternamn              349 non-null    object
#  7   tilltalsnamn           349 non-null    object
#  8   sorteringsnamn         349 non-null    object
#  9   iort                   349 non-null    object
#  10  parti                  349 non-null    object
#  11  valkrets               349 non-null    object
#  12  status                 349 non-null    object
#  13  person_url_xml         349 non-null    object
#  14  bild_url_80            349 non-null    object
#  15  bild_url_192           349 non-null    object
#  16  bild_url_max           349 non-null    object
#  17  personuppdrag.uppdrag  349 non-null    object
#  18  personuppgift.uppgift  349 non-null    object
# dtypes: object(19)
# memory usage: 51.9+ KB
#                             hangar_guid                              sourceid  \
# 0  8c9a4aa9-99e8-423c-bcc6-0e051f3d65e3  6a1b02dd-bdc4-4019-ab3e-dfeb133018ed
# 1  3e474339-386d-4b7a-95fe-401e610f85ed  e97a0939-8ba6-40c6-973e-2cc03cfb475c
# 2  6a9bb2b0-6be1-4593-bfdf-3943bab0411b  d3874590-31fb-4743-8d55-2565df5ed8af
# 3  825528d6-ccb4-4482-bbc4-dbc75a3dbd59  b00db2a8-378a-440c-982e-af62d234ed95
# 4  545b0392-55f7-4413-a2ff-571460ec4f04  8380b7c7-5994-4ea9-be2d-f404736dc0b8
#
#    intressent_id hangar_id fodd_ar     kon      efternamn tilltalsnamn  \
# 0  0121939297619   2343113    1960     man         El-Haj        Jamal
# 1  0161972600410   5146582    1968  kvinna        Widding         Elsa
# 2  0852475703226   5003692    1974  kvinna  Delgado Varas       Lorena
# 3    07012286624   2369687    1991     man         Riazat       Daniel
# 4  0930305890123   3057376    1976  kvinna         Bjälkö    Sara-Lena
#
#          sorteringsnamn iort parti           valkrets  \
# 0          El-Haj,Jamal          -       Malmö kommun
# 1          Widding,Elsa          -  Stockholms kommun
# 2  Delgado Varas,Lorena          -  Stockholms kommun
# 3         Riazat,Daniel          -     Stockholms län
# 4      Bjälkö,Sara-Lena          -       Hallands län
#
#                           status  \
# 0  Tjänstgörande riksdagsledamot
# 1  Tjänstgörande riksdagsledamot
# 2  Tjänstgörande riksdagsledamot
# 3  Tjänstgörande riksdagsledamot
# 4  Tjänstgörande riksdagsledamot
#
#                                       person_url_xml  \
# 0  https://data.riksdagen.se/person/6a1b02dd-bdc4...
# 1  https://data.riksdagen.se/person/e97a0939-8ba6...
# 2  https://data.riksdagen.se/person/d3874590-31fb...
# 3  https://data.riksdagen.se/person/b00db2a8-378a...
# 4  https://data.riksdagen.se/person/8380b7c7-5994...
#
#                                          bild_url_80  \
# 0  https://data.riksdagen.se/filarkiv/bilder/leda...
# 1  https://data.riksdagen.se/filarkiv/bilder/leda...
# 2  https://data.riksdagen.se/filarkiv/bilder/leda...
# 3  https://data.riksdagen.se/filarkiv/bilder/leda...
# 4  https://data.riksdagen.se/filarkiv/bilder/leda...
#
#                                         bild_url_192  \
# 0  https://data.riksdagen.se/filarkiv/bilder/leda...
# 1  https://data.riksdagen.se/filarkiv/bilder/leda...
# 2  https://data.riksdagen.se/filarkiv/bilder/leda...
# 3  https://data.riksdagen.se/filarkiv/bilder/leda...
# 4  https://data.riksdagen.se/filarkiv/bilder/leda...
#
#                                         bild_url_max  \
# 0  https://data.riksdagen.se/filarkiv/bilder/leda...
# 1  https://data.riksdagen.se/filarkiv/bilder/leda...
# 2  https://data.riksdagen.se/filarkiv/bilder/leda...
# 3  https://data.riksdagen.se/filarkiv/bilder/leda...
# 4  https://data.riksdagen.se/filarkiv/bilder/leda...
#
#                                personuppdrag.uppdrag  \
# 0  [{'organ_kod': 'kam', 'roll_kod': 'Riksdagsled...
# 1  [{'organ_kod': 'kam', 'roll_kod': 'Riksdagsled...
# 2  [{'organ_kod': 'kam', 'roll_kod': 'Riksdagsled...
# 3  [{'organ_kod': 'kam', 'roll_kod': 'Riksdagsled...
# 4  [{'organ_kod': 'kam', 'roll_kod': 'Riksdagsled...
#
#                                personuppgift.uppgift
# 0  [{'kod': 'HarBild', 'uppgift': ['true'], 'typ'...
# 1  [{'kod': 'HarBild', 'uppgift': ['true'], 'typ'...
# 2  [{'kod': 'HarBild', 'uppgift': ['true'], 'typ'...
# 3  [{'kod': 'HarBild', 'uppgift': ['true'], 'typ'...
# 4  [{'kod': 'HarBild', 'uppgift': ['true'], 'typ'...
# ['-' 'C' 'KD' 'L' 'M' 'MP' 'S' 'SD' 'V']
